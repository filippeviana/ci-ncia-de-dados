# %% [markdown]
# <a href="https://colab.research.google.com/github/filippeviana/ci-ncia-de-dados/blob/main/Dataframe_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
matematica = df_mat/24 *100
portugues = df_por/18 *100
geografia = df_geo/8 *100
ingles = df_ing/8 *100
historia = df_his/8 *100
fisica = df_fis/12 *100
quimica = df_qui/12 *100
display(matematica,portugues,geografia,ingles,historia,fisica,quimica)
# Out:
#     Qt_acertos
# 0    25.000000
# 1    79.166667
# 2    58.333333
# 3    41.666667
# 4    29.166667
# ..         ...
# 95   25.000000
# 96   33.333333
# 97   95.833333
# 98    0.000000
# 99   45.833333
#
# [100 rows x 1 columns]
#     Qt_acertos
# 0    38.888889
# 1    55.555556
# 2    88.888889
# 3    38.888889
# 4    11.111111
# ..         ...
# 95   22.222222
# 96    5.555556
# 97   27.777778
# 98   55.555556
# 99   83.333333
#
# [100 rows x 1 columns]
#     Qt_acertos
# 0         87.5
# 1          0.0
# 2          0.0
# 3         37.5
# 4         25.0
# ..         ...
# 95        87.5
# 96        50.0
# 97         0.0
# 98        37.5
# 99         0.0
#
# [100 rows x 1 columns]
#     Qt_acertos
# 0         37.5
# 1          0.0
# 2         62.5
# 3         50.0
# 4         87.5
# ..         ...
# 95        12.5
# 96        75.0
# 97        25.0
# 98        12.5
# 99        12.5
#
# [100 rows x 1 columns]
#     Qt_acertos
# 0         12.5
# 1          0.0
# 2         87.5
# ...

# %%
# 2) Seu código
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
display(total)
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
total = total/90 * 100
display(total)
# Out:
#     Qt_acertos
# 0    38.888889
# 1    53.333333
# 2    55.555556
# 3    35.555556
# 4    33.333333
# ..         ...
# 95   37.777778
# 96   30.000000
# 97   44.444444
# 98   44.444444
# 99   46.666667
#
# [100 rows x 1 columns]

# %%
# 4) Seu código aqui
alunos_aprovados = total[total['Qt_acertos']>=45]
display(alunos_aprovados)
alunos_aprovados.shape
# Out:
#     Qt_acertos
# 1    53.333333
# 2    55.555556
# 5    55.555556
# 7    54.444444
# 8    64.444444
# 11   47.777778
# 12   46.666667
# 17   57.777778
# 18   55.555556
# 20   58.888889
# 24   55.555556
# 27   55.555556
# 29   48.888889
# 31   60.000000
# 34   50.000000
# 35   53.333333
# 36   62.222222
# 37   57.777778
# 39   54.444444
# 40   52.222222
# 42   53.333333
# 44   47.777778
# 45   53.333333
# 48   61.111111
# 50   47.777778
# 51   46.666667
# 52   45.555556
# 53   50.000000
# 55   45.555556
# 60   53.333333
# 62   51.111111
# 67   51.111111
# 68   47.777778
# 70   68.888889
# 71   58.888889
# 72   55.555556
# 75   46.666667
# 77   58.888889
# 78   73.333333
# 80   50.000000
# 81   61.111111
# 82   47.777778
# 83   46.666667
# 88   55.555556
# 89   70.000000
# 93   62.222222
# 99   46.666667
# (47, 1)

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
re_mat = df_mat[df_mat['Qt_acertos']<=0]
re_fis = df_fis[df_fis['Qt_acertos']<=0]
re_qui = df_qui[df_qui['Qt_acertos']<=0]
re = [re_mat,re_fis,re_qui]
reprovados = pd.concat(re)
reprovados.rename(columns={'Qt_acertos':'Reprovados'},inplace=True)
reprovados.join(historia)
reprovados.join(geografia)
aprovados = pd.DataFrame(data=alunos_aprovados)
display(aprovados,reprovados)
# Out:
#     Qt_acertos
# 1    53.333333
# 2    55.555556
# 5    55.555556
# 7    54.444444
# 8    64.444444
# 11   47.777778
# 12   46.666667
# 17   57.777778
# 18   55.555556
# 20   58.888889
# 24   55.555556
# 27   55.555556
# 29   48.888889
# 31   60.000000
# 34   50.000000
# 35   53.333333
# 36   62.222222
# 37   57.777778
# 39   54.444444
# 40   52.222222
# 42   53.333333
# 44   47.777778
# 45   53.333333
# 48   61.111111
# 50   47.777778
# 51   46.666667
# 52   45.555556
# 53   50.000000
# 55   45.555556
# 60   53.333333
# 62   51.111111
# 67   51.111111
# 68   47.777778
# 70   68.888889
# 71   58.888889
# 72   55.555556
# 75   46.666667
# 77   58.888889
# 78   73.333333
# 80   50.000000
# 81   61.111111
# 82   47.777778
# 83   46.666667
# 88   55.555556
# 89   70.000000
# 93   62.222222
# 99   46.666667
#     Reprovados
# 25           0
# 94           0
# 98           0
# 3            0
# 6            0
# 12           0
# 26           0
# 35           0
# 49           0
# ...

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-5ed92752-6121-474f-ab37-816918134afc.c000.csv'

# %%
vacina = pd.read_csv ('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-57b36029-2318-4e43-a34b-76360bd18faf.c000.csv',sep=';')
vacina_acre = pd.DataFrame(data=vacina)
vacina_acre.head()
# Out:
#                                  document_id  \
# 0  b63af233-21d8-4af7-9aa9-3f8ff6285753-i0b0
# 1  b12754ca-9782-4640-9629-5de5b259bb3d-i0b0
# 2  ad099eee-6582-4fa0-ac02-c520237d7eed-i0b0
# 3  b16a9d8e-ef06-45a1-bc90-c5122c1be487-i0b0
# 4  d2676704-b600-474c-98ed-14afec02b245-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  3fdd86b8842269eda2dd906eb0aa15473ae1b5f8e64f1c...              49
# 1  df9c7a54127b5c0fa08953aca8834a4bedcfe466ef5a1f...              24
# 2  f56c5670b9907b8ca51387a37b67dfe41a203b3688bbe1...              20
# 3  516a5683a8f2e26f9680ee469dc93ee26694fd6b1c4f08...              19
# 4  69810caa482ee3b0370cd2f42200961fd72220f3942207...              16
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1972-03-16                          M                        3
# 1              1998-09-05                          M                        3
# ...

# %%
# 1)
vacinas_rg = vacina_acre['vacina_fabricante_nome'].nunique()
vacinas_rg
# Out:
# 13

# %%
# 2)
total_de_vacinados= vacina_acre['paciente_id'].nunique(	)
total_de_vacinados
# Out:
# 318850

# %%
# 3) solução alternativa
vacina_acre['primeira_dose']=0
vacina_acre.loc[vacina_acre['vacina_descricao_dose'] =='1ª Dose','primeira_dose']=1
vacina_acre['primeira_dose'].sum()
# Out:
# 144117

# %%
# 4)
vacina_acre['menores']=0
vacina_acre.loc[vacina_acre['paciente_idade'] < 18 ,'menores']=1
vacina_acre['menores'].sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 390906    0
# 390907    1
# 390908    0
# 390909    0
# 390910    0
# Name: menores, Length: 390911, dtype: int64

# %%
# 5)
vacina_acre['estabelecimento_razaoSocial'].nunique()
# Out:
# 64

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
menores = vacina_acre['paciente_idade']<18
df_menores = vacina_acre[menores]
df_menores.head()
# Out:
#                                   document_id  \
# 4   d2676704-b600-474c-98ed-14afec02b245-i0b0
# 11  b1d87025-4bcd-4da0-a898-8706f6384a65-i0b0
# 12  aa547f0a-65ca-46ba-91c6-c83655b8953d-i0b0
# 13  b1dec827-67a6-4d15-bb7a-faba68a25c83-i0b0
# 20  da990148-fee6-4a03-8749-372e6eed06db-i0b0
#
#                                           paciente_id  paciente_idade  \
# 4   69810caa482ee3b0370cd2f42200961fd72220f3942207...              16
# 11  82413637d0d77397a18603710269e6cc95ab483035a9b0...               6
# 12  e5e7bd969de58025aa558c0497f13da6549069936e6aab...               7
# 13  7a3b94f3ed81df06fe789fc48fc31b1b5cf840e6055cc0...              16
# 20  21a783ec2f32be4c28e9b52d1b3af2e3c1a5f84b995b5e...               7
#
#    paciente_dataNascimento paciente_enumSexoBiologico  \
# 4               2005-10-12                          F
# 11              2017-02-26                          F
# 12              2014-04-24                          M
# ...

# %%
# 2)
df_menores = pd.DataFrame(data=df_menores)
lista = df_menores.columns
lista = list(lista)
lista
# Out:
# ['document_id',
#  'paciente_id',
#  'paciente_idade',
#  'paciente_dataNascimento',
#  'paciente_enumSexoBiologico',
#  'paciente_racaCor_codigo',
#  'paciente_racaCor_valor',
#  'paciente_endereco_coIbgeMunicipio',
#  'paciente_endereco_coPais',
#  'paciente_endereco_nmMunicipio',
#  'paciente_endereco_nmPais',
#  'paciente_endereco_uf',
#  'paciente_endereco_cep',
#  'paciente_nacionalidade_enumNacionalidade',
#  'estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'vacina_grupoAtendimento_codigo',
#  'vacina_grupoAtendimento_nome',
#  'vacina_categoria_codigo',
#  'vacina_categoria_nome',
#  'vacina_lote',
#  'vacina_fabricante_nome',
#  'vacina_fabricante_referencia',
#  'vacina_dataAplicacao',
#  'vacina_descricao_dose',
#  'vacina_codigo',
#  'vacina_nome',
#  'sistema_origem',
#  'primeira_dose',
#  'menores']

# %%
# 3)
df_menores['vacina_categoria_nome'].nunique()
# Out:
# 14

# %%
# 4)
lista_locais = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
lista_locais
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %%
# 5)
df_menores.loc[0:,'estabelecimento_valor':
 'estabelecimento_uf']
# Out:
#         estabelecimento_valor  \
# 4                     6748759
# 11                    2002132
# 12                    6917291
# 13                    6159087
# 20                    2001225
# ...                       ...
# 390881                2000660
# 390885                5354072
# 390892                6934013
# 390894                2001225
# 390907                6917291
#
#                               estabelecimento_razaoSocial  \
# 4       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 11                      PREFEITURA MUN DE MAL THAUMATURGO
# 12                     PREFEITURA MUNICIPAL DE RIO BRANCO
# 13                PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                         PREFEITURA MUNICIPAL DE XAPURI
# ...                                                   ...
# 390881           PREFEITURA MUNICIPAL DE SENADOR GUIOMARD
# 390885                     PREFEITURA MUNICIPAL DE JORDAO
# 390892                      PREFEITURA MUNICIPAL DE FEIJO
# ...

# %%
estabelecimentos = df_menores.loc[0:,'estabelecimento_valor':
 'estabelecimento_uf'].drop_duplicates()
estabelecimentos
# Out:
#         estabelecimento_valor  \
# 4                     6748759
# 11                    2002132
# 12                    6917291
# 13                    6159087
# 20                    2001225
# ...                       ...
# 190674                2001357
# 253051                 783722
# 257283                2001837
# 322750                6411312
# 366867                2832798
#
#                               estabelecimento_razaoSocial  \
# 4       DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 11                      PREFEITURA MUN DE MAL THAUMATURGO
# 12                     PREFEITURA MUNICIPAL DE RIO BRANCO
# 13                PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 20                         PREFEITURA MUNICIPAL DE XAPURI
# ...                                                   ...
# 190674         SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 253051                      SECRETARIA MUNICIPAL DE SAUDE
# 257283                 PREFEITURA MUNICIPAL DE RIO BRANCO
# ...

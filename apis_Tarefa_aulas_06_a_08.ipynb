# %% [markdown]
# <a href="https://colab.research.google.com/github/filippeviana/ci-ncia-de-dados/blob/main/apis_Tarefa_aulas_06_a_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests
import numpy as np

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
r = requests.get(url)
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df.head()
# Out:
#    id_pleito tipo_interessado               interessado  cod_ibge  uf num_pvl  \
# 0       8074        Município                São Carlos   3548906  SP    None
# 1       8083        Município  Nossa Senhora do Socorro   2804805  SE    None
# 2       8133        Município                     Caeté   3110004  MG    None
# 3       8142        Município                   Remanso   2926004  BA    None
# 4       7770        Município             Porto Vitória   4120309  PR    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.000707/2014-72  2014-11-03T00:00:00Z
# 1                        Deferido  17944.000709/2014-61  2014-05-27T00:00:00Z
# 2                        Deferido  17944.000720/2014-21  2014-10-14T00:00:00Z
# 3  Arquivado por decurso de prazo  17944.000722/2014-11  2015-09-04T00:00:00Z
# 4                        Deferido  17944.000651/2013-75  2013-07-18T00:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# 4  Operação contratual interna
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1                             PAC 2 - Pró-Transporte
# 2                             PAC 2 - Pró-Transporte
# 3  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 4                                     Infraestrutura
#
#                        tipo_credor                            credor moeda  \
# 0  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 1  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 2  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 3  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 4  Instituição Financeira Nacional  Agência de Fomento do Paraná S/A  Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0   6083448.22                 0                      0  19/02/2015
# 1   4835263.45                 1                      0  25/06/2014
# 2   4200000.00                 1                      1  23/10/2014
# 3  11372547.62                 0                      0  02/03/2016
# 4    450000.00                 0                      0  08/08/2013

# %%
df.columns
# Out:
# Index(['id_pleito', 'tipo_interessado', 'interessado', 'cod_ibge', 'uf',
#        'num_pvl', 'status', 'num_processo', 'data_protocolo', 'tipo_operacao',
#        'finalidade', 'tipo_credor', 'credor', 'moeda', 'valor',
#        'pvl_assoc_divida', 'pvl_contradado_credor', 'data_status'],
#       dtype='object')

# %%
# 2) Seu código aqui
df[['finalidade','status']].value_counts()
# Out:
# finalidade                                      status
# Infraestrutura                                  Deferido                                                 992
#                                                 Deferido (PVL-IF)                                        876
# Aquisição de máquinas, equipamentos e veículos  Deferido (PVL-IF)                                        299
#                                                 Deferido                                                 296
# Infraestrutura                                  Encaminhado à PGFN com manifestação técnica favorável    167
#                                                                                                         ...
# Preservação e recuperação ambiental             Deferido                                                   1
# Educação                                        Arquivado a pedido                                         1
#                                                 Em retificação pelo interessado                            1
# Plano Diretor                                   Arquivado por decurso de prazo                             1
# Turismo                                         Deferido                                                   1
# Name: count, Length: 246, dtype: int64

# %%
# 3) Seu código aqui
df['ano_status'] = df['data_status'].str.slice(start=6)
df.head()
# Out:
#    id_pleito tipo_interessado               interessado  cod_ibge  uf num_pvl  \
# 0       8074        Município                São Carlos   3548906  SP    None
# 1       8083        Município  Nossa Senhora do Socorro   2804805  SE    None
# 2       8133        Município                     Caeté   3110004  MG    None
# 3       8142        Município                   Remanso   2926004  BA    None
# 4       7770        Município             Porto Vitória   4120309  PR    None
#
#                            status          num_processo        data_protocolo  \
# 0  Arquivado por decurso de prazo  17944.000707/2014-72  2014-11-03T00:00:00Z
# 1                        Deferido  17944.000709/2014-61  2014-05-27T00:00:00Z
# 2                        Deferido  17944.000720/2014-21  2014-10-14T00:00:00Z
# 3  Arquivado por decurso de prazo  17944.000722/2014-11  2015-09-04T00:00:00Z
# 4                        Deferido  17944.000651/2013-75  2013-07-18T00:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# 4  Operação contratual interna
#
#                                           finalidade  \
# 0  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 1                             PAC 2 - Pró-Transporte
# 2                             PAC 2 - Pró-Transporte
# 3  PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 4                                     Infraestrutura
#
#                        tipo_credor                            credor moeda  \
# 0  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 1  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 2  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 3  Instituição Financeira Nacional           Caixa Econômica Federal  Real
# 4  Instituição Financeira Nacional  Agência de Fomento do Paraná S/A  Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status ano_status
# 0   6083448.22                 0                      0  19/02/2015       2015
# 1   4835263.45                 1                      0  25/06/2014       2014
# 2   4200000.00                 1                      1  23/10/2014       2014
# 3  11372547.62                 0                      0  02/03/2016       2016
# 4    450000.00                 0                      0  08/08/2013       2013

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_pvl(uf, tipo_interessado):
    # Formatar a url com os parâmetros passados
    url = f"https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado={tipo_interessado}"
    # Fazer a requisição
    resposta = requests.get(url)
    # Verificar se a requisição foi bem-sucedida
    if resposta.status_code == 200:
        # Obter os dados no formato JSON
        data_json = resposta.json()
        # Criar o DataFrame
        dataFrame = pd.DataFrame(data_json['items'])
        return dataFrame
    else:
        return f"Erro na requisição: {resposta.status_code}"



dataframe = consulta_pvl('MG','Estado')
display(dataframe.head())
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0      20534           Estado  Minas Gerais        31  MG
# 1      11328           Estado  Minas Gerais        31  MG
# 2      22379           Estado  Minas Gerais        31  MG
# 3       6811           Estado  Minas Gerais        31  MG
# 4       4926           Estado  Minas Gerais        31  MG
#
#                 num_pvl                                             status  \
# 0  00000.000000/2017-69                     Arquivado por decurso de prazo
# 1                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2  00000.000000/2031-08                                 Arquivado pela STN
# 3                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4                  None                                          Arquivado
#
#            num_processo        data_protocolo  \
# 0  17944.001113/2015-60  2017-07-26T00:00:00Z
# 1  17944.001412/2012-51  2012-12-11T00:00:00Z
# 2  17944.000548/2016-78  2016-12-21T00:00:00Z
# 3  17944.000435/2008-62  2008-03-06T00:00:00Z
# 4  10951.000367/1998-24  1998-05-12T00:00:00Z
#
#                                        tipo_operacao          finalidade  \
# 0                        Operação contratual interna                PMAE
# 1  Operação contratual interna (com garantia da U...      Multissetorial
# 2  Operação contratual interna (com garantia da U...  Aditivo contratual
# 3  Operação contratual externa (com garantia da U...      Multissetorial
# 4  Operação contratual externa (com garantia da U...      Infraestrutura
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1       Instituição Financeira Nacional
# 2       Instituição Financeira Nacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
#
#                                               credor          moeda  \
# 0  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1                                Banco do Brasil S/A           Real
# 2                                Banco do Brasil S/A           Real
# 3  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  7.668000e+06                 0                      0  16/03/2018
# 1  3.653733e+09                 1                      0  03/01/2013
# 2  4.537330e+08                 0                      0  16/10/2017
# 3  9.760000e+08                 1                      0  02/07/2008
# 4  1.650000e+08                 0                      0  24/07/2002

# %%
minas = (df['uf']== 'MG')&(df['status']=='Arquivado por decurso de prazo')
df[minas]['status'].value_counts()
# Out:
# status
# Arquivado por decurso de prazo    56
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
bahia = (df['uf']=='BA')&(df['status']=='Deferido')
df[bahia][['interessado','status']].value_counts()
# Out:
# interessado             status
# Bahia                   Deferido    15
# Luís Eduardo Magalhães  Deferido     5
# Alagoinhas              Deferido     4
# Itatim                  Deferido     3
# Jequié                  Deferido     2
#                                     ..
# Itaparica               Deferido     1
# Itiruçu                 Deferido     1
# Jaguarari               Deferido     1
# Alcobaça                Deferido     1
# Wanderley               Deferido     1
# Name: count, Length: 70, dtype: int64

# %%
# 4) Seu código aqui
ba = (df['uf']=='BA')
salvador = pd.DataFrame(df[ba])
salvador.rename(columns={'interessado':'Estado'},inplace=True)
salvador.to_csv('salvador.csv')
